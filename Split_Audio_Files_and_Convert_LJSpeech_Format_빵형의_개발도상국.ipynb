# %% [markdown]
# # Split Audio Files and Convert LJSpeech Format
#
# 유튜브 [빵형의 개발도상국](https://www.youtube.com/@bbanghyong)
#
# 1. 유튜브 영상 다운로드 (음성만 다운로드, mp3) - PyTube
# 2. Speech to Text (Transcribe) - OpenAI Whisper (Local)

# %%
# !sudo apt update && sudo apt install ffmpeg
# !pip install -q openai-whisper pytube tiktoken
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [736 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,076 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,952 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,914 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,533 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,347 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,812 kB]
# Fetched 10.6 MB in 3s (3,584 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 39 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 85.6 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %% [markdown]
# ## Download YouTube video
#
# [파운데이션 모델 AWS에서 사용해보기 - 생성형AI 무료 세미나 보러오세요~!](https://www.youtube.com/watch?v=ojSItxrdjMs) - 빵형의 개발도상국 유튜브 채널

# %%
from pytube import YouTube

yt = YouTube('https://youtu.be/ojSItxrdjMs?si=CmhwsxyBQIfqsL6a')

yt.streams.filter(only_audio=True).first().download(
    output_path='.', filename='input.mp3')
# Out:
# '/content/./input.mp3'

# %% [markdown]
# ## Transcribe

# %%
import whisper

model = whisper.load_model("small")
# Out:
# 100%|████████████████████████████████████████| 461M/461M [00:03<00:00, 133MiB/s]

# %% [markdown]
# 30초 이상 오디오 데이터 처리 방법
#
# https://github.com/openai/whisper/discussions/136

# %%
result = model.transcribe("input.mp3")

result["text"][:300]
# Out:
# ' 우주 고양이 아주 잘 만든 거 볼 수 있죠? 제가 얼마 전에 써봤을 때보다 성능이 굉장히 좋아진 것 같은데요? 이렇게 되게 말끔하게 나왔습니다 이게 조금 마음에 드니까 나중에 저장을 해서 사용을 해야겠어요 이렇게 잘 나왔는데 로어 월 단계 세이로빵입니다 오늘은 생상형 AI와 데이터를 사용해서 채트 GPTI 같은 여러분들만의 서비스를 만들고 싶은 분들이나 인공지능 및 기계학습을 통해서 인물부터 심화까지 딥다이브하면서 뭔가 서비스를 만들어보고 싶은 분들을 위한 컴퍼너스를 소개해드리려고 하는데요 바로 AWS에서 준비한 AWS 이노베이트'

# %%
result["segments"][:3]
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 2.66,
#   'text': ' 우주 고양이 아주 잘 만든 거 볼 수 있죠?',
#   'tokens': [50364,
#    14995,
#    5836,
#    48105,
#    1129,
#    22360,
#    6644,
#    40628,
#    3675,
#    18001,
#    4446,
#    34070,
#    30,
#    50497],
#   'temperature': 0.0,
#   'avg_logprob': -0.42841730708569553,
#   'compression_ratio': 1.45565749235474,
#   'no_speech_prob': 0.033967986702919006},
#  {'id': 1,
#   'seek': 0,
#   'start': 2.66,
#   'end': 7.54,
#   'text': ' 제가 얼마 전에 써봤을 때보다 성능이 굉장히 좋아진 것 같은데요?',
#   'tokens': [50497,
#    7439,
#    44859,
#    27117,
#    37113,
#    3891,
#    23560,
#    1638,
#    9057,
#    27655,
#    14409,
#    16102,
#    1129,
#    15509,
#    10805,
#    8097,
#    4431,
#    21864,
#    1495,
#    30,
#    50741],
#   'temperature': 0.0,
#   'avg_logprob': -0.42841730708569553,
#   'compression_ratio': 1.45565749235474,
#   'no_speech_prob': 0.033967986702919006},
#  {'id': 2,
#   'seek': 0,
#   'start': 7.54,
#   'end': 10.34,
#   'text': ' 이렇게 되게 말끔하게 나왔습니다',
#   'tokens': [50741, 5483, 14860, 31336, 30895, 8601, 26374, 3115, 50881],
#   'temperature': 0.0,
#   'avg_logprob': -0.42841730708569553,
#   'compression_ratio': 1.45565749235474,
#   'no_speech_prob': 0.033967986702919006}]

# %%
len(result["text"])
# Out:
# 5294

# %%
for r in result['segments']:
    print(f'[{r["start"]:.2f} --> {r["end"]:.2f}] {r["text"]}')
# Out:
# [0.00 --> 2.66]  우주 고양이 아주 잘 만든 거 볼 수 있죠?
# [2.66 --> 7.54]  제가 얼마 전에 써봤을 때보다 성능이 굉장히 좋아진 것 같은데요?
# [7.54 --> 10.34]  이렇게 되게 말끔하게 나왔습니다
# [10.34 --> 14.24]  이게 조금 마음에 드니까 나중에 저장을 해서 사용을 해야겠어요
# [14.24 --> 15.34]  이렇게 잘 나왔는데
# [18.00 --> 20.14]  로어 월 단계 세이로빵입니다
# [20.14 --> 23.84]  오늘은 생상형 AI와 데이터를 사용해서
# [23.84 --> 28.64]  채트 GPTI 같은 여러분들만의 서비스를 만들고 싶은 분들이나
# [28.64 --> 30.98]  인공지능 및 기계학습을 통해서
# [30.98 --> 34.28]  인물부터 심화까지 딥다이브하면서
# [34.28 --> 36.98]  뭔가 서비스를 만들어보고 싶은 분들을 위한
# [36.98 --> 38.84]  컴퍼너스를 소개해드리려고 하는데요
# [38.84 --> 44.08]  바로 AWS에서 준비한 AWS 이노베이트 AI MLN 데이터 에디션
# [44.08 --> 45.98]  이거를 소개해드릴까 합니다
# [45.98 --> 50.28]  컴퍼너스 알자는 2024년 2월 22일 날 개최가 되고요
# [50.28 --> 52.58]  2가 3개로 외우시면 편하겠죠?
# [52.58 --> 54.18]  2, 2, 2 이렇게요
# [54.18 --> 57.90]  그래서 생상형 AI에 포커스가 되어서
# [57.90 --> 59.20]  컴퍼너스가 진행이 됩니다
# [59.20 --> 62.74]  특히 채트 GPTI와 같은 텍트 생성형 AI
# [62.74 --> 64.64]  채팅 생성형 AI
# [64.64 --> 69.50]  그리고 스테브드 피전과 같은 이미지 생성 AI의 초점이 맞춰서
# [69.50 --> 71.04]  컴퍼너스가 진행되고
# [71.04 --> 75.34]  여러분들만의 서비스를 만들 수 있는 방법도 알려준다고 해요
# [75.34 --> 77.20]  그래서 강의한 목록을 보면은
# [77.20 --> 79.74]  이렇게 트랙 1, 2, 3로 되어 있는데요
# [79.74 --> 81.64]  트랙 1번은 개발자를 위한
# [81.64 --> 84.54]  완전관리형 생성형 AI 서비스
# [84.54 --> 87.04]  트랙 2번은 생성의에 잘 몰라도
# [87.04 --> 89.58]  쉽게 구현하는 생성형 AI 서비스
# [89.58 --> 93.04]  트랙 3번은 시스템 설계의 실정 꿀팁
# [93.04 --> 94.18]  이걸 소개한다고 합니다
# [94.18 --> 97.68]  특히 포스코, 튼스케어 등의 기업이 실제로
# [97.68 --> 101.64]  생성의 AI 기술을 활용한 사례를 소개한다고 하니까
# [101.64 --> 103.04]  굉장히 재미있을 것 같은데요
# [103.04 --> 105.64]  각 세션이 30분마다 진행이 되는데
# [105.64 --> 107.14]  이번에는 약간 특이하게
# [107.14 --> 110.28]  업무 시간 동안 참여하기 어려운 분들을 위해서
# [110.28 --> 113.28]  똑같은 세션을 3번을 반복한다고 합니다
# [113.28 --> 115.24]  그래서 2월 22일 날
# [115.24 --> 118.24]  오전 9시부터 12시까지도 들을 수 있고
# [118.24 --> 120.84]  오후 2시부터 5시에도 들을 수 있고
# [120.84 --> 124.74]  퇴근하고 나서 오후 7시에서 10시까지도 들을 수 있습니다
# [124.74 --> 126.94]  여러분들이 원하는 시간을
# [126.94 --> 130.74]  1, 2, 3 중에 선택해서 들으실 수 있다는 장점이 있죠
# [130.74 --> 132.74]  제가 참 좋아하는 AWS의
# [132.74 --> 135.04]  태크애반젤리스트 윤석찬 님이
# [135.04 --> 136.84]  기조 강연을 맡고 있습니다
# [136.84 --> 138.94]  그래서 많은 관심 부탁드리고요
# [138.94 --> 142.54]  또한 AI 전문가들이 1대1로 Q&A를 진행해서
# [142.54 --> 145.34]  기꼬 풍넓은 학습기회를 제공한다고 하니까
# [145.34 --> 148.04]  꼭 참석하셔서 보시면 좋을 것 같습니다
# [148.04 --> 150.34]  행사 등록 링크는 영상 설명란이나
# [150.34 --> 151.94]  댓글에 달아 놓을 테니까
# [151.94 --> 155.14]  그걸 클릭해가지고 등록해 주시면 좋겠습니다
# [155.14 --> 159.44]  제가 오늘 이 컴퍼런스에서 다룰 주제 중에
# [159.44 --> 163.04]  아마존 배드락이라는 서비스가 있어요
# [163.04 --> 165.14]  그래서 이게 어떤 식으로 동작하고
# [165.14 --> 166.94]  어떤 것들이 있는지
# [166.94 --> 169.94]  한번 이번 영상에서 같이 살펴보려고 합니다
# [169.94 --> 172.04]  아마존 배드락이라는 것은
# [172.04 --> 174.44]  기본 모델, 파운데이션 모델이죠
# [174.44 --> 176.54]  그래서 메타의 라마툴 라든지
# [176.54 --> 179.54]  아마존에서도 파운데이션 모델 냈었어요
# [179.54 --> 182.54]  이미지 생성형 AI라고 하면 스테브 디퓨전 같은
# [182.54 --> 185.14]  그런 파운데이션 모델을 사용해서
# [185.14 --> 187.54]  생성형 AI 애플리케이션을 구축하고
# [187.54 --> 189.94]  굉장히 쉽게 핸들링할 수 있는
# [189.94 --> 191.94]  그런 솔루션을 제공하고 있습니다
# [191.94 --> 193.74]  가격도 굉장히 저렴한 편이에요
# [193.74 --> 196.44]  그래서 개발자들이 쉽게 접근해서
# [196.44 --> 198.84]  생성형 AI 서비스를 만들 수 있습니다
# [198.84 --> 201.24]  또한 아마존 배드락을 사용하면
# [201.24 --> 203.74]  파운데이션 모델을 커스터모로
# [203.74 --> 206.14]  파인 튜닝할 수 있는 기능도 제공하고 있어요
# [206.14 --> 208.14]  당연히 이 서비스에 사용하면
# [208.14 --> 210.84]  AWS의 보안믹 개인정보보호
# [210.84 --> 213.14]  이것도 동시에 적용이 되니까
# [213.14 --> 215.74]  보안 문제를 해결할 수가 있다
# [215.74 --> 217.24]  파운데이션 모델 중에서
# [217.24 --> 218.94]  여러분들이 원하는 걸 선택하거나
# [218.94 --> 221.94]  아니면 여러분의 데이터를 사용해서
# [221.94 --> 224.94]  모델을 비공개로 파인 튜닝
# [224.94 --> 226.84]  미세 조정을 할 수 있습니다
# [226.84 --> 228.64]  또한 이런 것들을 사용해서
# [228.64 --> 232.24]  검색 증강 생성 R-AZ
# [232.24 --> 235.34]  레그 모델을 데이터베이스를 통해서
# [235.34 --> 237.34]  실제 데이터를 찾아와서
# [237.34 --> 238.44]  증강시켜서
# [238.44 --> 240.44]  좀 더 인리치먼트 시켜서
# [240.44 --> 243.14]  뿌려주는 서비스를 만들 수도 있고요
# [243.14 --> 244.94]  에이전트를 만들 수도 있습니다
# [244.94 --> 247.14]  하루 밤 사이에 뉴스를
# [247.14 --> 250.54]  다 요약해서 메일로 뿌려주는 에이전트라든지
# [250.54 --> 251.94]  특별한 기능을 수행하는
# [251.94 --> 253.94]  에이전트를 따로 만들 수도 있고요
# [253.94 --> 256.74]  그래서 다양한 모델들을 제공하고 있는데
# [256.74 --> 258.84]  한번 직접 사용해 보면서
# [258.84 --> 260.74]  어떤 것들이 있는지 살펴보도록 하죠
# [260.74 --> 263.54]  그래서 아마존의 배드락 서비스에 접속하면
# [263.54 --> 265.74]  이렇게 화면이 나옵니다
# [265.74 --> 268.04]  그런데 여러분들이 처음 접속하시면은
# [268.04 --> 269.44]  모델 액세스
# [269.44 --> 270.24]  여기에 들어가서
# [270.24 --> 272.14]  어떤 모델을 사용할 건지
# [272.14 --> 274.04]  선택하실 수 있거든요
# [274.04 --> 276.84]  그래서 모델 액세스 관리를 누르셔 가지고
# [276.84 --> 278.74]  어떤 모델을 사용할 건지
# [278.74 --> 280.74]  이렇게 체크 표시로
# [280.74 --> 284.14]  선택을 해서 이용 신청을 할 수 있습니다
# [284.14 --> 286.64]  저는 이용 신청한 지 얼마 안 돼 가지고
# [286.64 --> 289.24]  액세스 권한이 부여된 게 몇 개 안 돼요
# [289.24 --> 291.44]  메타의 라마2
# [291.44 --> 294.34]  이 라마2도 제가 예전에 콜렙에서 사용하는 방법을
# [294.34 --> 295.34]  알려드렸었는데
# [295.34 --> 297.04]  그것보다 더 쉽게
# [297.04 --> 299.44]  API로 사용할 수 있습니다
# [299.44 --> 302.74]  일단 이렇게 UI상에서 사용하는 방법이 있어요
# [302.74 --> 305.44]  지금 플레일그라운드라고 되어 있는 부분에
# [305.44 --> 307.94]  채팅, 텍스트, 이미지라고 되어 있는데
# [307.94 --> 310.14]  여기서 플레일그라운드 채팅을 누르면
# [310.14 --> 313.24]  이 UI상에서 직접 한번 테스트 해볼 수 있습니다
# [313.24 --> 315.54]  그래서 모델을 한번 선택을 해볼게요
# [315.54 --> 319.24]  제가 승인 받은 모델은 AI21, 랩스랑, 아마존이랑
# [319.24 --> 320.84]  이렇게 두 개가 있거든요
# [320.84 --> 325.44]  아마존의 타이탄, 텍스트, G1, 익스프레스를 사용해 보도록 할게요
# [325.44 --> 328.44]  주의하셔야 될 점은 이게 공짜가 아니라는 점입니다
# [328.44 --> 331.24]  토큰당 금액을 내셔야 돼요, 온 디맨트로
# [331.24 --> 332.24]  그래서
# [332.24 --> 333.74]  안녕하세요
# [333.74 --> 334.84]  이렇게 하고서
# [334.84 --> 338.04]  실행을 누르면
# [338.04 --> 340.04]  지금 한글은 안 되는 것 같습니다
# [340.04 --> 341.74]  하이, 때요
# [341.74 --> 343.14]  이렇게 입력을 해서
# [343.14 --> 344.14]  지금 보시
# [344.14 --> 345.74]  Hello, how can I help you?
# [345.74 --> 346.44]  아, 만족?
# [348.04 --> 351.34]  김치를 만드는 레시피를 알고 싶어
# [351.34 --> 354.74]  김치 레시피를 지금 알려주고 있네요
# [354.74 --> 357.44]  그럼요, 여기 김치 담그는 법이 있습니다
# [357.44 --> 361.34]  속을 파내고 체선, 나파, 양배추, 소금 어쩌고 다쪄고
# [361.34 --> 362.44]  해서
# [362.44 --> 365.34]  큰 그릇에 양배추와 소금 물을 넣고 섞어주고
# [365.34 --> 367.04]  참고로 정확한 발효 시간은
# [367.04 --> 369.84]  거주지역의 온도와 습도에 따라 달라질 수 있습니다
# [369.84 --> 372.44]  이렇게 텍스트 모델을 사용해 볼 수가 있고
# [372.44 --> 374.84]  오른쪽에 보시면 체츠피티와 같이
# [374.84 --> 376.84]  이런 템파레쳐, 온도가 템파레쳐죠
# [376.84 --> 378.74]  템파레쳐가 높을수록
# [378.74 --> 381.74]  더 다양한 창의적인 답변을 생성해 낼 거고요
# [381.74 --> 383.74]  그다음부터 응답 길이도 토큰수죠
# [383.74 --> 386.54]  토큰수도 이렇게 조절할 수가 있고
# [386.54 --> 389.64]  지금 같은 경우는 유저라는 답변이 나오면
# [389.64 --> 391.64]  중지하도록 되어 있습니다
# [391.64 --> 393.84]  중지를 어느 시점에서 할 것인지
# [393.84 --> 395.44]  어떤 단어가 나오면
# [395.44 --> 396.94]  중지를 시킬 것인지
# [396.94 --> 397.94]  이거를
# [397.94 --> 399.94]  시퀀스를 추가할 수도 있고요
# [399.94 --> 402.84]  밑에 보니까 모델 지표가 나오는데
# [402.84 --> 405.94]  타이탄 텍스트주의 익스프레스를 사용했을 때
# [405.94 --> 409.14]  지연 시간은 9900ms
# [409.14 --> 412.44]  그니까 9초 정도가 걸렸다고 나와 있고
# [412.44 --> 415.04]  입력 토큰수가 79
# [415.04 --> 418.04]  출력 토큰수가 373이고
# [418.04 --> 420.84]  0.00074달러
# [420.84 --> 422.34]  이 정도 하는데
# [422.34 --> 424.04]  이 정도 가격이 된다는 얘기입니다
# [424.04 --> 425.84]  1원도 안 들리는 거죠? 이러면
# [425.84 --> 428.24]  굉장히 저렴한 가격으로 사용할 수가 있다
# [428.24 --> 429.64]  그리고 이번에는 이미지
# [429.64 --> 430.64]  또 해보도록 하겠습니다
# [430.64 --> 432.24]  이미지 플레이그라운드에서
# [432.24 --> 433.84]  이번에도 마찬가지로
# [433.84 --> 435.34]  아마존에서 만든
# [435.34 --> 437.74]  타이탄 이미지 제너레이터 G1
# [437.74 --> 439.54]  이건 지금 편가판이거든요
# [439.54 --> 441.94]  그래서 나중에 바뀔 수 있다는
# [441.94 --> 444.74]  그런 걸 좀 인지를 해주시면 좋을 것 같고요
# [444.74 --> 446.04]  적용한 다음에
# [446.04 --> 446.94]  여기서
# [446.94 --> 449.34]  아래쪽에 프럼프트를 입력할 수 있습니다
# [449.34 --> 451.34]  스페이스 캣
# [451.34 --> 454.24]  우주 고양이를 그려보도록 할게요
# [454.24 --> 455.14]  실행 눌러서
# [455.14 --> 457.34]  고양이를 그려보겠습니다
# [457.34 --> 458.94]  아마 이미지 생성 모델이
# [458.94 --> 462.34]  크기가 지금 1,014, 1,014로 돼 있어서
# [462.34 --> 464.44]  조금 시간이 걸릴 것 같아요
# [464.44 --> 467.24]  네, 한 40초 정도 기다리니까
# [467.24 --> 468.74]  이렇게 결과가 나왔습니다
# [468.74 --> 471.34]  우주 고양이 아주 잘 만든 거 볼 수 있죠?
# [471.34 --> 474.24]  제가 얼마 전에 써봤을 때보다
# [474.24 --> 476.14]  성능이 굉장히 좋아진 것 같은데요
# [476.14 --> 479.34]  이렇게 되게 말끔하게 나왔습니다
# [479.34 --> 481.24]  또한 요거를 가지고
# [481.24 --> 482.34]  변형 생성
# [482.34 --> 483.54]  베리에이션이죠
# [483.54 --> 485.94]  요거와 비슷한 것들을 또 생성해내거나
# [485.94 --> 486.74]  또 편집
# [486.74 --> 487.64]  이렇게 해서
# [487.64 --> 490.14]  그 인페인팅을 한다든지
# [490.14 --> 491.54]  이런 식으로 계속해서
# [491.54 --> 493.64]  뭔가 새로운 것을 만들어낼 수 있습니다
# [493.64 --> 494.94]  요 오른쪽에 보시면
# [494.94 --> 497.84]  또 새로운 모드들을 제공을 하는데요
# [497.84 --> 498.54]  아까 만들었던
# [498.54 --> 500.54]  제니레이트 생성 모드가 있고
# [500.54 --> 501.94]  에디트 모드가 있어요
# [501.94 --> 503.04]  그다음에 여기서
# [503.04 --> 504.64]  제니레이트 모드에서 보면
# [504.64 --> 505.84]  네거티브 프럼프트
# [505.84 --> 507.54]  나오면 안 되는 것들
# [507.54 --> 508.74]  요것도 이제 프럼프트를
# [508.74 --> 510.74]  네거티브로 입력할 수가 있고
# [510.74 --> 512.64]  참조 이미지를 넣어서
# [512.64 --> 513.74]  이미지를 참조해서
# [513.74 --> 515.44]  그러니까 이미지 투 이미지죠
# [515.44 --> 516.74]  스테브 디퓨전을 따지면
# [516.74 --> 518.24]  요것도 만들 수 있고
# [518.24 --> 519.34]  품질도
# [519.34 --> 520.34]  이건 아마
# [520.34 --> 521.24]  그걸 것 같아요
# [521.24 --> 522.24]  이터레이션이겠죠
# [522.24 --> 522.94]  이터레이션
# [522.94 --> 524.24]  표준으로 하면
# [524.24 --> 526.54]  이터레이션은 40정도 돌고
# [526.54 --> 528.14]  프리미엄으로 하면 80정도 돌고
# [528.14 --> 529.14]  더 많이 돌아서
# [529.14 --> 532.24]  더 고품질의 이미지를 생성해낼 수 있고
# [532.24 --> 533.94]  아 오리엔테이션은
# [533.94 --> 534.84]  랜드 스케이프인지
# [534.84 --> 535.74]  폴트레이트인지
# [535.74 --> 537.84]  그러니까 가로로 누워 있는 이미지인지
# [537.84 --> 539.64]  세로로 서 있는 이미지인지
# [539.64 --> 541.34]  요거를 선택하는 것 같습니다
# [541.34 --> 542.74]  그다음에 크기
# [542.74 --> 544.74]  요것도 선택할 수가 있고
# [544.74 --> 546.04]  이미지 개수
# [546.04 --> 547.74]  아마 이미지 개수를 줄이면
# [547.74 --> 549.74]  더 빠르게 생성될 거고요
# [549.74 --> 551.54]  그다음에 프럼프트 강도
# [551.54 --> 553.04]  이거는 그거죠
# [553.04 --> 554.74]  스트렁스죠 스트렁스
# [554.74 --> 558.24]  그래서 지금 프럼프트를 얼마나 더 잘 지킬 것인가
# [558.24 --> 559.54]  강도를 낮추면
# [559.54 --> 562.34]  더 창의적으로 생성해낼 거고
# [562.34 --> 563.54]  강도를 높이면
# [563.54 --> 566.14]  제가 입력한 프럼프트에 좀 더 맞춰서
# [566.14 --> 567.44]  생성을 할 거고요
# [567.44 --> 569.74]  시에드도 이렇게 조정을 할 수 있습니다
# [569.74 --> 571.94]  이렇게 해서 이미지 플레이 그라운드도
# [571.94 --> 573.94]  사용하는 방법을 한번 알려드렸고
# [573.94 --> 575.74]  이게 조금 마음에 드니까
# [575.74 --> 577.84]  나중에 저장을 해서 사용을 해야겠어요
# [577.84 --> 579.04]  굉장히 잘 나왔는데
# [579.04 --> 581.04]  이렇게 한번 사용을 해봤는데
# [581.04 --> 583.64]  비용이 얼마나 나오는지 궁금해가지고
# [583.64 --> 584.64]  한번 봤거든요
# [584.64 --> 586.74]  그래서 지금 아마존
# [586.74 --> 587.54]  배드락
# [587.54 --> 590.54]  이쪽 보면 제가 총 0.57달러 정도 썼는데
# [590.54 --> 592.54]  한 7,800원 정도 쓴 거 같아요
# [592.54 --> 594.94]  일단 타이탄 이미지 제너레이터로
# [594.94 --> 597.54]  57개의 이미지를 사용했는데
# [597.54 --> 599.04]  0.57달러
# [599.04 --> 600.14]  거의 뭐
# [600.14 --> 601.74]  이미지 1개당
# [601.74 --> 603.54]  한 1원? 2원 정도
# [603.54 --> 604.54]  나오는 거 같고요
# [604.54 --> 606.54]  그다음에 타이탄 텍스트 G1
# [606.54 --> 608.04]  라이트 사용해서
# [608.04 --> 613.14]  1K 토큰당 0.003달러입니다
# [613.14 --> 614.04]  그래서
# [614.04 --> 615.84]  아마 내림 처리를 했는지
# [615.84 --> 617.54]  0달러가 청구가 됐고요
# [617.54 --> 619.34]  그 다음 아웃토큰도
# [619.34 --> 622.14]  이제 0.00004달러인데
# [622.14 --> 623.34]  0달러 처리가 돼서
# [623.34 --> 624.84]  결국은 텍스트는
# [624.84 --> 626.64]  제가 테스트를 해봤는데
# [626.64 --> 628.64]  0달러가 청구가 됐고
# [628.64 --> 629.94]  이미지만
# [629.94 --> 631.74]  조금 청구가 돼서 결국
# [631.74 --> 633.44]  0.57달러가
# [633.44 --> 635.74]  생성된 것을 볼 수 있었습니다
# [635.74 --> 636.24]  네
# [636.24 --> 637.14]  저렴하죠
# [637.14 --> 638.94]  가격은 이 정도 된다
# [638.94 --> 639.94]  가격은
# [639.94 --> 641.84]  이 리점마다 달라질 수 있습니다
# [641.84 --> 644.14]  또한 아마존 배드락의
# [644.14 --> 645.64]  공식 문서를 보면은
# [645.64 --> 646.84]  이렇게 플레이그라운드에서
# [646.84 --> 648.54]  사용하는 방법뿐만 아니라
# [648.54 --> 650.14]  파이선, 자바스크립트,
# [650.14 --> 651.34]  자바 등의
# [651.34 --> 653.94]  AWS SDK를 사용해서
# [653.94 --> 654.94]  이런 식으로
# [654.94 --> 655.94]  구현할 수가 있어요
# [655.94 --> 656.54]  코드로
# [656.54 --> 658.94]  그래서 개발자들한테 굉장히 편한
# [658.94 --> 661.74]  서비스를 제공하고 있다는 점
# [661.74 --> 662.84]  그래서 이걸로 가지고
# [662.84 --> 664.84]  고성능의 GPU가 없더라도
# [664.84 --> 667.94]  AWS 아마존 배드락을 사용해서
# [667.94 --> 669.84]  굉장히 쉽게 파운데이션 모델
# [669.84 --> 671.94]  또는 여러분들의 커스텀 모델을
# [671.94 --> 673.94]  서비스할 수 있다는 점을
# [673.94 --> 675.64]  한번 소개를 해드렸습니다
# [675.64 --> 677.64]  그래서 AWS 이노베이트
# [677.64 --> 679.84]  AI MLN 데이터 에디션
# [679.84 --> 682.54]  이 컴퍼런스를 한번 소개를 해드리면서
# [682.54 --> 685.04]  아마존 배드락에 대해서 설명을 드렸고요
# [685.04 --> 686.74]  조금 더 아마존 배드락이나
# [686.74 --> 689.44]  다른 생성형 AI 서비스들에 대해서
# [689.44 --> 691.64]  더 잘 알고 싶다 하시는 분들은
# [691.64 --> 693.74]  이 컴퍼런스 무료니까
# [693.74 --> 695.54]  꼭 한번 등록해놓으셨다가
# [695.54 --> 696.94]  들어보시면 좋을 것 같습니다
# [696.94 --> 698.34]  컴퍼런스 등록 링크는
# [698.34 --> 699.94]  영상 하단 설명란과
# [699.94 --> 702.04]  댓글란에 달아 놓을 테니까
# [702.04 --> 703.94]  그 링크를 꼭 클릭하셔가지고
# [703.94 --> 705.44]  등록하시길 바래요
# [705.44 --> 706.84]  네 오늘 영상 여기까지고
# [706.84 --> 707.94]  재밌게 보셨다면
# [707.94 --> 710.04]  구독과 좋아요 부탁드립니다
# [710.04 --> 711.54]  다음에 더 신기하고
# [711.54 --> 714.34]  재미있는 프로젝트로 만나도록 할게요
# [714.34 --> 715.54]  안녕

# %%
# !mkdir wavs

# %%
for i, r in enumerate(result['segments']):
    # !ffmpeg -y -i input.mp3 -ss {r["start"]} -to {r["end"]} -hide_banner -loglevel error wavs/audio{i+1}.wav

# %%
from IPython.display import Audio

Audio("wavs/audio1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
with open("metadata.txt", "w", encoding="utf-8") as f:
    for i, r in enumerate(result['segments']):
        f.write(f"audio{i+1}|{r['text'].strip()}|{r['text'].strip()}\n")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/drive/MyDrive/bbanghyong-tts-dataset
# !zip -r bbanghyong.zip /content/wavs /content/metadata.txt
# !cp -a /content/bbanghyong.zip /content/drive/MyDrive/bbanghyong-tts-dataset
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/bbanghyong-tts-dataset’: File exists
#   adding: content/wavs/ (stored 0%)
#   adding: content/wavs/audio310.wav (deflated 31%)
#   adding: content/wavs/audio55.wav (deflated 37%)
#   adding: content/wavs/audio204.wav (deflated 34%)
#   adding: content/wavs/audio229.wav (deflated 27%)
#   adding: content/wavs/audio39.wav (deflated 29%)
#   adding: content/wavs/audio89.wav (deflated 34%)
#   adding: content/wavs/audio106.wav (deflated 38%)
#   adding: content/wavs/audio151.wav (deflated 31%)
#   adding: content/wavs/audio86.wav (deflated 32%)
#   adding: content/wavs/audio209.wav (deflated 32%)
#   adding: content/wavs/audio133.wav (deflated 33%)
#   adding: content/wavs/audio284.wav (deflated 18%)
#   adding: content/wavs/audio200.wav (deflated 38%)
#   adding: content/wavs/audio175.wav (deflated 33%)
#   adding: content/wavs/audio308.wav (deflated 30%)
#   adding: content/wavs/audio196.wav (deflated 40%)
#   adding: content/wavs/audio210.wav (deflated 37%)
#   adding: content/wavs/audio42.wav (deflated 30%)
#   adding: content/wavs/audio292.wav (deflated 37%)
#   adding: content/wavs/audio259.wav (deflated 24%)
#   adding: content/wavs/audio70.wav (deflated 31%)
#   adding: content/wavs/audio218.wav (deflated 34%)
#   adding: content/wavs/audio258.wav (deflated 24%)
#   adding: content/wavs/audio146.wav (deflated 28%)
#   adding: content/wavs/audio114.wav (deflated 22%)
#   adding: content/wavs/audio117.wav (deflated 33%)
#   adding: content/wavs/audio122.wav (deflated 29%)
#   adding: content/wavs/audio326.wav (deflated 33%)
#   adding: content/wavs/audio193.wav (deflated 35%)
#   adding: content/wavs/audio173.wav (deflated 39%)
#   adding: content/wavs/audio44.wav (deflated 22%)
#   adding: content/wavs/audio29.wav (deflated 31%)
#   adding: content/wavs/audio315.wav (deflated 36%)
#   adding: content/wavs/audio1.wav (deflated 38%)
#   adding: content/wavs/audio290.wav (deflated 31%)
#   adding: content/wavs/audio180.wav (deflated 34%)
#   adding: content/wavs/audio71.wav (deflated 34%)
#   adding: content/wavs/audio191.wav (deflated 28%)
#   adding: content/wavs/audio38.wav (deflated 23%)
#   adding: content/wavs/audio306.wav (deflated 32%)
#   adding: content/wavs/audio307.wav (deflated 30%)
#   adding: content/wavs/audio270.wav (deflated 29%)
#   adding: content/wavs/audio271.wav (deflated 34%)
#   adding: content/wavs/audio331.wav (deflated 34%)
#   adding: content/wavs/audio305.wav (deflated 26%)
#   adding: content/wavs/audio37.wav (deflated 27%)
#   adding: content/wavs/audio28.wav (deflated 32%)
#   adding: content/wavs/audio301.wav (deflated 27%)
#   adding: content/wavs/audio154.wav (deflated 24%)
#   adding: content/wavs/audio121.wav (deflated 35%)
#   adding: content/wavs/audio160.wav (deflated 41%)
#   adding: content/wavs/audio45.wav (deflated 32%)
#   adding: content/wavs/audio98.wav (deflated 31%)
#   adding: content/wavs/audio128.wav (deflated 34%)
#   adding: content/wavs/audio252.wav (deflated 37%)
#   adding: content/wavs/audio124.wav (deflated 27%)
#   adding: content/wavs/audio329.wav (deflated 41%)
#   adding: content/wavs/audio73.wav (deflated 28%)
#   adding: content/wavs/audio64.wav (deflated 32%)
#   adding: content/wavs/audio293.wav (deflated 22%)
#   adding: content/wavs/audio24.wav (deflated 30%)
#   adding: content/wavs/audio320.wav (deflated 35%)
#   adding: content/wavs/audio166.wav (deflated 34%)
#   adding: content/wavs/audio65.wav (deflated 28%)
#   adding: content/wavs/audio50.wav (deflated 25%)
#   adding: content/wavs/audio34.wav (deflated 28%)
#   adding: content/wavs/audio318.wav (deflated 33%)
#   adding: content/wavs/audio182.wav (deflated 37%)
#   adding: content/wavs/audio142.wav (deflated 30%)
#   adding: content/wavs/audio309.wav (deflated 38%)
#   adding: content/wavs/audio224.wav (deflated 34%)
#   adding: content/wavs/audio246.wav (deflated 29%)
#   adding: content/wavs/audio140.wav (deflated 32%)
#   adding: content/wavs/audio303.wav (deflated 35%)
#   adding: content/wavs/audio268.wav (deflated 25%)
#   adding: content/wavs/audio216.wav (deflated 36%)
#   adding: content/wavs/audio272.wav (deflated 30%)
#   adding: content/wavs/audio63.wav (deflated 30%)
#   adding: content/wavs/audio186.wav (deflated 33%)
#   adding: content/wavs/audio285.wav (deflated 40%)
#   adding: content/wavs/audio212.wav (deflated 30%)
#   adding: content/wavs/audio281.wav (deflated 27%)
#   adding: content/wavs/audio227.wav (deflated 25%)
#   adding: content/wavs/audio25.wav (deflated 29%)
#   adding: content/wavs/audio185.wav (deflated 39%)
#   adding: content/wavs/audio18.wav (deflated 20%)
#   adding: content/wavs/audio177.wav (deflated 34%)
#   adding: content/wavs/audio165.wav (deflated 35%)
#   adding: content/wavs/audio201.wav (deflated 42%)
#   adding: content/wavs/audio179.wav (deflated 32%)
#   adding: content/wavs/audio150.wav (deflated 30%)
#   adding: content/wavs/audio291.wav (deflated 33%)
#   adding: content/wavs/audio4.wav (deflated 29%)
#   adding: content/wavs/audio283.wav (deflated 29%)
#   adding: content/wavs/audio47.wav (deflated 34%)
#   adding: content/wavs/audio102.wav (deflated 32%)
#   adding: content/wavs/audio219.wav (deflated 34%)
#   adding: content/wavs/audio231.wav (deflated 33%)
#   adding: content/wavs/audio298.wav (deflated 36%)
#   adding: content/wavs/audio10.wav (deflated 28%)
#   adding: content/wavs/audio134.wav (deflated 35%)
#   adding: content/wavs/audio249.wav (deflated 31%)
#   adding: content/wavs/audio162.wav (deflated 28%)
#   adding: content/wavs/audio234.wav (deflated 32%)
#   adding: content/wavs/audio222.wav (deflated 35%)
#   adding: content/wavs/audio105.wav (deflated 28%)
#   adding: content/wavs/audio78.wav (deflated 30%)
#   adding: content/wavs/audio67.wav (deflated 31%)
#   adding: content/wavs/audio164.wav (deflated 30%)
#   adding: content/wavs/audio74.wav (deflated 32%)
#   adding: content/wavs/audio192.wav (deflated 37%)
#   adding: content/wavs/audio330.wav (deflated 28%)
#   adding: content/wavs/audio116.wav (deflated 36%)
#   adding: content/wavs/audio17.wav (deflated 35%)
#   adding: content/wavs/audio261.wav (deflated 24%)
#   adding: content/wavs/audio27.wav (deflated 28%)
#   adding: content/wavs/audio299.wav (deflated 30%)
#   adding: content/wavs/audio181.wav (deflated 35%)
#   adding: content/wavs/audio324.wav (deflated 36%)
#   adding: content/wavs/audio245.wav (deflated 33%)
#   adding: content/wavs/audio188.wav (deflated 22%)
#   adding: content/wavs/audio207.wav (deflated 26%)
#   adding: content/wavs/audio240.wav (deflated 36%)
#   adding: content/wavs/audio41.wav (deflated 30%)
#   adding: content/wavs/audio83.wav (deflated 30%)
#   adding: content/wavs/audio31.wav (deflated 28%)
#   adding: content/wavs/audio143.wav (deflated 36%)
#   adding: content/wavs/audio232.wav (deflated 31%)
#   adding: content/wavs/audio99.wav (deflated 38%)
#   adding: content/wavs/audio119.wav (deflated 32%)
#   adding: content/wavs/audio158.wav (deflated 33%)
#   adding: content/wavs/audio60.wav (deflated 34%)
#   adding: content/wavs/audio277.wav (deflated 35%)
#   adding: content/wavs/audio62.wav (deflated 33%)
#   adding: content/wavs/audio138.wav (deflated 44%)
#   adding: content/wavs/audio75.wav (deflated 25%)
#   adding: content/wavs/audio77.wav (deflated 30%)
#   adding: content/wavs/audio226.wav (deflated 40%)
#   adding: content/wavs/audio137.wav (deflated 29%)
#   adding: content/wavs/audio256.wav (deflated 29%)
#   adding: content/wavs/audio157.wav (deflated 33%)
#   adding: content/wavs/audio304.wav (deflated 33%)
#   adding: content/wavs/audio187.wav (deflated 38%)
#   adding: content/wavs/audio81.wav (deflated 35%)
#   adding: content/wavs/audio20.wav (deflated 31%)
#   adding: content/wavs/audio247.wav (deflated 26%)
#   adding: content/wavs/audio51.wav (deflated 31%)
#   adding: content/wavs/audio161.wav (deflated 29%)
#   adding: content/wavs/audio139.wav (deflated 34%)
#   adding: content/wavs/audio319.wav (deflated 34%)
#   adding: content/wavs/audio7.wav (deflated 27%)
#   adding: content/wavs/audio148.wav (deflated 21%)
#   adding: content/wavs/audio248.wav (deflated 29%)
#   adding: content/wavs/audio168.wav (deflated 31%)
#   adding: content/wavs/audio9.wav (deflated 28%)
#   adding: content/wavs/audio97.wav (deflated 25%)
#   adding: content/wavs/audio110.wav (deflated 37%)
#   adding: content/wavs/audio274.wav (deflated 27%)
#   adding: content/wavs/audio275.wav (deflated 29%)
#   adding: content/wavs/audio12.wav (deflated 28%)
#   adding: content/wavs/audio15.wav (deflated 33%)
#   adding: content/wavs/audio101.wav (deflated 38%)
#   adding: content/wavs/audio208.wav (deflated 29%)
#   adding: content/wavs/audio104.wav (deflated 34%)
#   adding: content/wavs/audio233.wav (deflated 28%)
#   adding: content/wavs/audio163.wav (deflated 30%)
#   adding: content/wavs/audio230.wav (deflated 31%)
#   adding: content/wavs/audio267.wav (deflated 30%)
#   adding: content/wavs/audio48.wav (deflated 37%)
#   adding: content/wavs/audio211.wav (deflated 25%)
#   adding: content/wavs/audio156.wav (deflated 26%)
#   adding: content/wavs/audio56.wav (deflated 27%)
#   adding: content/wavs/audio59.wav (deflated 39%)
#   adding: content/wavs/audio183.wav (deflated 38%)
#   adding: content/wavs/audio279.wav (deflated 30%)
#   adding: content/wavs/audio112.wav (deflated 33%)
#   adding: content/wavs/audio90.wav (deflated 32%)
#   adding: content/wavs/audio323.wav (deflated 24%)
#   adding: content/wavs/audio317.wav (deflated 28%)
#   adding: content/wavs/audio302.wav (deflated 39%)
#   adding: content/wavs/audio296.wav (deflated 32%)
#   adding: content/wavs/audio149.wav (deflated 40%)
#   adding: content/wavs/audio189.wav (deflated 30%)
#   adding: content/wavs/audio223.wav (deflated 28%)
#   adding: content/wavs/audio239.wav (deflated 43%)
#   adding: content/wavs/audio127.wav (deflated 25%)
#   adding: content/wavs/audio273.wav (deflated 26%)
#   adding: content/wavs/audio167.wav (deflated 26%)
#   adding: content/wavs/audio311.wav (deflated 41%)
#   adding: content/wavs/audio194.wav (deflated 26%)
#   adding: content/wavs/audio221.wav (deflated 34%)
#   adding: content/wavs/audio312.wav (deflated 26%)
#   adding: content/wavs/audio262.wav (deflated 31%)
#   adding: content/wavs/audio255.wav (deflated 34%)
#   adding: content/wavs/audio174.wav (deflated 33%)
#   adding: content/wavs/audio108.wav (deflated 30%)
#   adding: content/wavs/audio269.wav (deflated 28%)
#   adding: content/wavs/audio250.wav (deflated 22%)
#   adding: content/wavs/audio79.wav (deflated 35%)
#   adding: content/wavs/audio5.wav (deflated 40%)
#   adding: content/wavs/audio23.wav (deflated 34%)
#   adding: content/wavs/audio96.wav (deflated 34%)
#   adding: content/wavs/audio2.wav (deflated 28%)
#   adding: content/wavs/audio159.wav (deflated 34%)
#   adding: content/wavs/audio123.wav (deflated 30%)
#   adding: content/wavs/audio100.wav (deflated 29%)
#   adding: content/wavs/audio93.wav (deflated 23%)
#   adding: content/wavs/audio276.wav (deflated 25%)
#   adding: content/wavs/audio136.wav (deflated 38%)
#   adding: content/wavs/audio52.wav (deflated 31%)
#   adding: content/wavs/audio178.wav (deflated 36%)
#   adding: content/wavs/audio199.wav (deflated 32%)
#   adding: content/wavs/audio85.wav (deflated 29%)
#   adding: content/wavs/audio169.wav (deflated 33%)
#   adding: content/wavs/audio325.wav (deflated 32%)
#   adding: content/wavs/audio107.wav (deflated 35%)
#   adding: content/wavs/audio54.wav (deflated 29%)
#   adding: content/wavs/audio130.wav (deflated 31%)
#   adding: content/wavs/audio72.wav (deflated 30%)
#   adding: content/wavs/audio68.wav (deflated 28%)
#   adding: content/wavs/audio58.wav (deflated 27%)
#   adding: content/wavs/audio243.wav (deflated 34%)
#   adding: content/wavs/audio19.wav (deflated 35%)
#   adding: content/wavs/audio126.wav (deflated 34%)
#   adding: content/wavs/audio35.wav (deflated 36%)
#   adding: content/wavs/audio118.wav (deflated 28%)
#   adding: content/wavs/audio153.wav (deflated 40%)
#   adding: content/wavs/audio147.wav (deflated 31%)
#   adding: content/wavs/audio225.wav (deflated 25%)
#   adding: content/wavs/audio235.wav (deflated 29%)
#   adding: content/wavs/audio53.wav (deflated 28%)
#   adding: content/wavs/audio8.wav (deflated 28%)
#   adding: content/wavs/audio205.wav (deflated 31%)
#   adding: content/wavs/audio327.wav (deflated 27%)
#   adding: content/wavs/audio43.wav (deflated 24%)
#   adding: content/wavs/audio280.wav (deflated 21%)
#   adding: content/wavs/audio197.wav (deflated 33%)
#   adding: content/wavs/audio14.wav (deflated 29%)
#   adding: content/wavs/audio66.wav (deflated 26%)
#   adding: content/wavs/audio145.wav (deflated 22%)
#   adding: content/wavs/audio132.wav (deflated 46%)
#   adding: content/wavs/audio33.wav (deflated 27%)
#   adding: content/wavs/audio95.wav (deflated 30%)
#   adding: content/wavs/audio214.wav (deflated 25%)
#   adding: content/wavs/audio69.wav (deflated 32%)
#   adding: content/wavs/audio135.wav (deflated 41%)
#   adding: content/wavs/audio295.wav (deflated 30%)
#   adding: content/wavs/audio22.wav (deflated 29%)
#   adding: content/wavs/audio36.wav (deflated 25%)
#   adding: content/wavs/audio286.wav (deflated 29%)
#   adding: content/wavs/audio152.wav (deflated 28%)
#   adding: content/wavs/audio172.wav (deflated 21%)
#   adding: content/wavs/audio294.wav (deflated 36%)
#   adding: content/wavs/audio244.wav (deflated 24%)
#   adding: content/wavs/audio242.wav (deflated 35%)
#   adding: content/wavs/audio61.wav (deflated 31%)
#   adding: content/wavs/audio254.wav (deflated 37%)
#   adding: content/wavs/audio109.wav (deflated 40%)
#   adding: content/wavs/audio13.wav (deflated 26%)
#   adding: content/wavs/audio287.wav (deflated 33%)
#   adding: content/wavs/audio297.wav (deflated 31%)
#   adding: content/wavs/audio202.wav (deflated 35%)
#   adding: content/wavs/audio236.wav (deflated 25%)
#   adding: content/wavs/audio314.wav (deflated 31%)
#   adding: content/wavs/audio49.wav (deflated 34%)
#   adding: content/wavs/audio251.wav (deflated 39%)
#   adding: content/wavs/audio88.wav (deflated 32%)
#   adding: content/wavs/audio103.wav (deflated 33%)
#   adding: content/wavs/audio141.wav (deflated 31%)
#   adding: content/wavs/audio40.wav (deflated 25%)
#   adding: content/wavs/audio82.wav (deflated 26%)
#   adding: content/wavs/audio57.wav (deflated 32%)
#   adding: content/wavs/audio257.wav (deflated 41%)
#   adding: content/wavs/audio129.wav (deflated 46%)
#   adding: content/wavs/audio288.wav (deflated 39%)
#   adding: content/wavs/audio190.wav (deflated 31%)
#   adding: content/wavs/audio328.wav (deflated 30%)
#   adding: content/wavs/audio26.wav (deflated 33%)
#   adding: content/wavs/audio170.wav (deflated 34%)
#   adding: content/wavs/audio46.wav (deflated 21%)
#   adding: content/wavs/audio228.wav (deflated 36%)
#   adding: content/wavs/audio265.wav (deflated 28%)
#   adding: content/wavs/audio313.wav (deflated 29%)
#   adding: content/wavs/audio144.wav (deflated 37%)
#   adding: content/wavs/audio155.wav (deflated 33%)
#   adding: content/wavs/audio87.wav (deflated 31%)
#   adding: content/wavs/audio282.wav (deflated 30%)
#   adding: content/wavs/audio30.wav (deflated 29%)
#   adding: content/wavs/audio289.wav (deflated 37%)
#   adding: content/wavs/audio111.wav (deflated 30%)
#   adding: content/wavs/audio94.wav (deflated 31%)
#   adding: content/wavs/audio91.wav (deflated 39%)
#   adding: content/wavs/audio213.wav (deflated 37%)
#   adding: content/wavs/audio203.wav (deflated 39%)
#   adding: content/wavs/audio263.wav (deflated 29%)
#   adding: content/wavs/audio316.wav (deflated 28%)
#   adding: content/wavs/audio217.wav (deflated 26%)
#   adding: content/wavs/audio332.wav (deflated 22%)
#   adding: content/wavs/audio266.wav (deflated 24%)
#   adding: content/wavs/audio11.wav (deflated 29%)
#   adding: content/wavs/audio84.wav (deflated 33%)
#   adding: content/wavs/audio115.wav (deflated 36%)
#   adding: content/wavs/audio32.wav (deflated 34%)
#   adding: content/wavs/audio6.wav (deflated 20%)
#   adding: content/wavs/audio264.wav (deflated 34%)
#   adding: content/wavs/audio113.wav (deflated 33%)
#   adding: content/wavs/audio241.wav (deflated 29%)
#   adding: content/wavs/audio237.wav (deflated 32%)
#   adding: content/wavs/audio76.wav (deflated 27%)
#   adding: content/wavs/audio80.wav (deflated 19%)
#   adding: content/wavs/audio321.wav (deflated 35%)
#   adding: content/wavs/audio21.wav (deflated 26%)
#   adding: content/wavs/audio16.wav (deflated 34%)
#   adding: content/wavs/audio3.wav (deflated 41%)
#   adding: content/wavs/audio198.wav (deflated 34%)
#   adding: content/wavs/audio131.wav (deflated 39%)
#   adding: content/wavs/audio253.wav (deflated 25%)
#   adding: content/wavs/audio278.wav (deflated 34%)
#   adding: content/wavs/audio176.wav (deflated 34%)
#   adding: content/wavs/audio300.wav (deflated 37%)
#   adding: content/wavs/audio215.wav (deflated 33%)
#   adding: content/wavs/audio171.wav (deflated 31%)
#   adding: content/wavs/audio220.wav (deflated 38%)
#   adding: content/wavs/audio322.wav (deflated 27%)
#   adding: content/wavs/audio195.wav (deflated 32%)
#   adding: content/wavs/audio120.wav (deflated 37%)
#   adding: content/wavs/audio184.wav (deflated 33%)
#   adding: content/wavs/audio260.wav (deflated 39%)
#   adding: content/wavs/audio92.wav (deflated 30%)
#   adding: content/wavs/audio206.wav (deflated 21%)
#   adding: content/wavs/audio238.wav (deflated 30%)
#   adding: content/wavs/audio125.wav (deflated 35%)
#   adding: content/metadata.txt (deflated 76%)
